# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

names =[]
urls=[]

def dogs(url):
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

##### find all the h3 tags with class and extract text from them ######

    for i in soup.findAll('h3', class_='breed-type-card__title'):
        ttl=i.getText()
        names.append(ttl)

##### find all the div tags with class and extract href from them ######
        
    for i in soup.findAll('div', class_='breed-type-card'):
        urls.append(i.a.get('href'))
   
 ### find all the div tags with class and extract href for next page untill condition become flase ######

    try:
        if soup.find('div', class_='mt2 bpm-mt5').a.get('href'):
            dogs(soup.find('div', class_='mt2 bpm-mt5').a.get('href')) 
    except:
        print("No More Pages")
 


dogs("https://www.akc.org/dog-breeds/")        
       
a = {
       "Names":names,
       "Urls" : urls
    }

df=pd.DataFrame(a)
df.to_csv('dogsa.csv',index=False)

df
# Out:
# No More Pages
#                  Names                                               Urls
# 0        Affenpinscher      https://www.akc.org/dog-breeds/affenpinscher/
# 1         Afghan Hound       https://www.akc.org/dog-breeds/afghan-hound/
# 2     Airedale Terrier   https://www.akc.org/dog-breeds/airedale-terrier/
# 3                Akita              https://www.akc.org/dog-breeds/akita/
# 4     Alaskan Klee Kai   https://www.akc.org/dog-breeds/alaskan-klee-kai/
# ..                 ...                                                ...
# 277  Wirehaired Vizsla  https://www.akc.org/dog-breeds/wirehaired-vizsla/
# 278     Working Kelpie     https://www.akc.org/dog-breeds/working-kelpie/
# 279     Xoloitzcuintli     https://www.akc.org/dog-breeds/xoloitzcuintli/
# 280     Yakutian Laika     https://www.akc.org/dog-breeds/yakutian-laika/
# 281  Yorkshire Terrier  https://www.akc.org/dog-breeds/yorkshire-terrier/
#
# [282 rows x 2 columns]
